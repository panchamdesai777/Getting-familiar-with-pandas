# %% [markdown]
# # IPL Dataset Analysis
#
# ## Problem Statement
# We want to know as to what happens during an IPL match which raises several questions in our mind with our limited knowledge about the game called cricket on which it is based. This analysis is done to know as which factors led one of the team to win and how does it matter.

# %% [markdown]
# ## About the Dataset :
# The Indian Premier League (IPL) is a professional T20 cricket league in India contested during April-May of every year by teams representing Indian cities. It is the most-attended cricket league in the world and ranks sixth among all the sports leagues. It has teams with players from around the world and is very competitive and entertaining with a lot of close matches between teams.
#
# The IPL and other cricket related datasets are available at [cricsheet.org](https://cricsheet.org/%c2%a0(data). Feel free to visit the website and explore the data by yourself as exploring new sources of data is one of the interesting activities a data scientist gets to do.
#
# Snapshot of the data you will be working on:<br>
# <br>
# The dataset 136522 data points and 23 features<br>
#
# |Features|Description|
# |-----|-----|
# |match_code|Code pertaining to individual match|
# |date|Date of the match played|
# |city|City where the match was played|
# |venue|Stadium in that city where the match was played|
# |team1|team1|
# |team2|team2|
# |toss_winner|Who won the toss out of two teams|
# |toss_decision|toss decision taken by toss winner|
# |winner|Winner of that match between two teams|
# |win_type|How did the team won(by wickets or runs etc.)|
# |win_margin|difference with which the team won|
# |inning|inning type(1st or 2nd)|
# |delivery|ball delivery|
# |batting_team|current team on batting|
# |batsman|current batsman on strike|
# |non_striker|batsman on non-strike|
# |bowler|Current bowler|
# |runs|runs scored|
# |extras|extra run scored|
# |total|total run scored on that delivery including runs and extras|
# |extras_type|extra run scored by wides or no ball or legby|
# |player_out|player that got out|
# |wicket_kind|How did the player got out|
# |wicket_fielders|Fielder who caught out the player by catch|

# %% [markdown]
# ### Analyzing data using pandas module

# %% [markdown]
# ### Read the data using pandas module.

# %%
import pandas as pd
import numpy as np
df_ipl = pd.read_csv('./data/ipl_dataset.csv')
df_ipl.shape
# Out:
# (136522, 24)

# %%
len(df_ipl['match_code'].unique())

# You can also use: 
#df_ipl['match_code'].nunique()
# Out:
# 577

# %% [markdown]
# ### There are certain fixed cities all around the world where matches are held. Find the list of unique cities where matches were played

# %%
# Corrected as Venues to Cities
df_ipl['city'].unique()
# Out:
# array(['East London', 'Port Elizabeth', 'Centurion', 'neutral_venue',
#        'Chennai', 'Jaipur', 'Kolkata', 'Delhi', 'Chandigarh', 'Hyderabad',
#        'Ranchi', 'Mumbai', 'Bangalore', 'Dharamsala', 'Pune', 'Rajkot',
#        'Durban', 'Cuttack', 'Cape Town', 'Ahmedabad', 'Johannesburg',
#        'Visakhapatnam', 'Abu Dhabi', 'Raipur', 'Kochi', 'Kimberley',
#        'Nagpur', 'Bloemfontein', 'Indore', 'Kanpur'], dtype=object)

# %% [markdown]
# ### Find the columns which contains null values if any ?

# %%
df_ipl.isnull().sum()
# Out:
# match_code              0
# date                    0
# city                    0
# venue                   0
# team1                   0
# team2                   0
# toss_winner             0
# toss_decision           0
# winner               1818
# win_type             1818
# win_margin           1818
# inning                  0
# delivery                0
# batting_team            0
# batsman                 0
# non_striker             0
# bowler                  0
# runs                    0
# extras                  0
# total                   0
# extras_type        129064
# player_out         129807
# wicket_kind        129807
# wicket_fielders    131657
# dtype: int64

# %% [markdown]
# ### Though the match is held in different cities all around the world it may or maynot have multiple venues (stadiums where matches are held) list down top 5 most played venues

# %%
d=df_ipl.groupby('match_code')['venue'].unique().value_counts()
d
d.head(5)
# Out:
# [M Chinnaswamy Stadium]              58
# [Eden Gardens]                       54
# [Feroz Shah Kotla]                   53
# [Wankhede Stadium]                   49
# [MA Chidambaram Stadium, Chepauk]    48
# Name: venue, dtype: int64

# %% [markdown]
# ### Make a runs vs run-count frequency table

# %%
df_ipl['total'].value_counts()
# Out:
# 1    56159
# 0    48739
# 4    15615
# 2     9343
# 6     5773
# 3      555
# 5      304
# 7       34
# Name: total, dtype: int64

# %% [markdown]
# ### IPL seasons are held every year now let's look at our data and extract how many seasons were recorded.

# %%
df_ipl['date']=pd.to_datetime(df_ipl['date'])
df_ipl['date'].dt.year.nunique()
# Out:
# 9

# %% [markdown]
# ### What are the total no. of matches played per season

# %%
df_ipl['date']=pd.to_datetime(df_ipl['date'])
df_ipl['year']= df_ipl['date'].dt.year
df_ipl.groupby('year')['match_code'].nunique()
# Out:
# year
# 2008    58
# 2009    57
# 2010    60
# 2011    73
# 2012    74
# 2013    76
# 2014    60
# 2015    59
# 2016    60
# Name: match_code, dtype: int64

# %% [markdown]
# ### What are the total runs scored across each season

# %%
df_ipl['date']=pd.to_datetime(df_ipl['date'])
df_ipl['year']= df_ipl['date'].dt.year
df_ipl.groupby('year')['total'].sum()
# Out:
# year
# 2008    17936
# 2009    16320
# 2010    18862
# 2011    21154
# 2012    22451
# 2013    22541
# 2014    18909
# 2015    18331
# 2016    18862
# Name: total, dtype: int64

# %% [markdown]
# ### There are teams which are high performing and low performing. Let's look at the aspect of performance of an individual team. Filter the data and aggregate the runs scored by each team. Display top 10 results which are having runs scored over 200.

# %%
df=df_ipl.groupby(['match_code', 'inning','team1','team2','winner'])['total'].sum().reset_index() 
df1=df[df['total']>=200]
df1.nlargest(10,'total')
# Out:
#       match_code  inning                        team1  \
# 692       598027       1  Royal Challengers Bangalore
# 1102      980987       1  Royal Challengers Bangalore
# 288       419137       1          Chennai Super Kings
# 2         335983       1              Kings XI Punjab
# 988       829795       1               Mumbai Indians
# 468       501260       1              Kings XI Punjab
# 394       501223       1             Delhi Daredevils
# 840       733987       1              Kings XI Punjab
# 1022      980907       1  Royal Challengers Bangalore
# 900       734047       1          Chennai Super Kings
#
#                             team2                       winner  total
# 692                 Pune Warriors  Royal Challengers Bangalore    263
# 1102                Gujarat Lions  Royal Challengers Bangalore    248
# 288              Rajasthan Royals          Chennai Super Kings    246
# 2             Chennai Super Kings          Chennai Super Kings    240
# 988   Royal Challengers Bangalore  Royal Challengers Bangalore    235
# 468   Royal Challengers Bangalore              Kings XI Punjab    232
# 394               Kings XI Punjab             Delhi Daredevils    231
# 840           Chennai Super Kings              Kings XI Punjab    231
# 1022          Sunrisers Hyderabad  Royal Challengers Bangalore    227
# 900               Kings XI Punjab              Kings XI Punjab    226

# %% [markdown]
# ### Chasing a 200+ target is difficulty in T-20 format. What are the chances that a team scoring runs above 200  in their 1st inning is chased by the opposition in 2nd inning.

# %%
filtered_df=pd.DataFrame(df_ipl.groupby(['match_code','batting_team' ,'inning','team1','team2','winner'])['total'].sum().reset_index()) 
filtered_df
# Out:
#       match_code                 batting_team  inning  \
# 0         335982        Kolkata Knight Riders       1
# 1         335982  Royal Challengers Bangalore       2
# 2         335983          Chennai Super Kings       1
# 3         335983              Kings XI Punjab       2
# 4         335984             Delhi Daredevils       2
# 5         335984             Rajasthan Royals       1
# 6         335985               Mumbai Indians       1
# 7         335985  Royal Challengers Bangalore       2
# 8         335986              Deccan Chargers       1
# 9         335986        Kolkata Knight Riders       2
# 10        335987              Kings XI Punjab       1
# 11        335987             Rajasthan Royals       2
# 12        335988              Deccan Chargers       1
# 13        335988             Delhi Daredevils       2
# 14        335989          Chennai Super Kings       1
# 15        335989               Mumbai Indians       2
# 16        335990              Deccan Chargers       1
# 17        335990             Rajasthan Royals       2
# 18        335991              Kings XI Punjab       1
# 19        335991               Mumbai Indians       2
# 20        335992             Rajasthan Royals       2
# 21        335992  Royal Challengers Bangalore       1
# 22        335993          Chennai Super Kings       2
# 23        335993        Kolkata Knight Riders       1
# 24        335994              Deccan Chargers       2
# 25        335994               Mumbai Indians       1
# 26        335995             Delhi Daredevils       1
# 27        335995              Kings XI Punjab       2
# 28        335996          Chennai Super Kings       1
# 29        335996  Royal Challengers Bangalore       2
# ...          ...                          ...     ...
# 1106      980991              Kings XI Punjab       1
# 1107      980991          Sunrisers Hyderabad       2
# 1108      980993             Delhi Daredevils       2
# 1109      980993               Mumbai Indians       1
# 1110      980995        Kolkata Knight Riders       1
# 1111      980995  Royal Challengers Bangalore       2
# 1112      980997             Delhi Daredevils       1
# 1113      980997      Rising Pune Supergiants       2
# 1114      980999              Kings XI Punjab       2
# 1115      980999  Royal Challengers Bangalore       1
# 1116      981001                Gujarat Lions       2
# 1117      981001        Kolkata Knight Riders       1
# 1118      981003             Delhi Daredevils       2
# 1119      981003          Sunrisers Hyderabad       1
# 1120      981005              Kings XI Punjab       1
# 1121      981005      Rising Pune Supergiants       2
# 1122      981007                Gujarat Lions       2
# 1123      981007               Mumbai Indians       1
# 1124      981009        Kolkata Knight Riders       1
# 1125      981009          Sunrisers Hyderabad       2
# 1126      981011             Delhi Daredevils       1
# 1127      981011  Royal Challengers Bangalore       2
# 1128      981013                Gujarat Lions       1
# 1129      981013  Royal Challengers Bangalore       2
# 1130      981015        Kolkata Knight Riders       2
# 1131      981015          Sunrisers Hyderabad       1
# 1132      981017                Gujarat Lions       1
# 1133      981017          Sunrisers Hyderabad       2
# 1134      981019  Royal Challengers Bangalore       2
# 1135      981019          Sunrisers Hyderabad       1
#
#                             team1                        team2  \
# 0     Royal Challengers Bangalore        Kolkata Knight Riders
# 1     Royal Challengers Bangalore        Kolkata Knight Riders
# 2                 Kings XI Punjab          Chennai Super Kings
# 3                 Kings XI Punjab          Chennai Super Kings
# 4                Delhi Daredevils             Rajasthan Royals
# 5                Delhi Daredevils             Rajasthan Royals
# 6                  Mumbai Indians  Royal Challengers Bangalore
# 7                  Mumbai Indians  Royal Challengers Bangalore
# 8           Kolkata Knight Riders              Deccan Chargers
# 9           Kolkata Knight Riders              Deccan Chargers
# 10               Rajasthan Royals              Kings XI Punjab
# 11               Rajasthan Royals              Kings XI Punjab
# 12                Deccan Chargers             Delhi Daredevils
# 13                Deccan Chargers             Delhi Daredevils
# 14            Chennai Super Kings               Mumbai Indians
# 15            Chennai Super Kings               Mumbai Indians
# 16                Deccan Chargers             Rajasthan Royals
# 17                Deccan Chargers             Rajasthan Royals
# 18                Kings XI Punjab               Mumbai Indians
# 19                Kings XI Punjab               Mumbai Indians
# 20    Royal Challengers Bangalore             Rajasthan Royals
# 21    Royal Challengers Bangalore             Rajasthan Royals
# 22            Chennai Super Kings        Kolkata Knight Riders
# 23            Chennai Super Kings        Kolkata Knight Riders
# 24                 Mumbai Indians              Deccan Chargers
# 25                 Mumbai Indians              Deccan Chargers
# 26                Kings XI Punjab             Delhi Daredevils
# 27                Kings XI Punjab             Delhi Daredevils
# 28    Royal Challengers Bangalore          Chennai Super Kings
# 29    Royal Challengers Bangalore          Chennai Super Kings
# ...                           ...                          ...
# 1106              Kings XI Punjab          Sunrisers Hyderabad
# 1107              Kings XI Punjab          Sunrisers Hyderabad
# 1108               Mumbai Indians             Delhi Daredevils
# 1109               Mumbai Indians             Delhi Daredevils
# 1110        Kolkata Knight Riders  Royal Challengers Bangalore
# 1111        Kolkata Knight Riders  Royal Challengers Bangalore
# 1112      Rising Pune Supergiants             Delhi Daredevils
# 1113      Rising Pune Supergiants             Delhi Daredevils
# 1114  Royal Challengers Bangalore              Kings XI Punjab
# 1115  Royal Challengers Bangalore              Kings XI Punjab
# 1116                Gujarat Lions        Kolkata Knight Riders
# 1117                Gujarat Lions        Kolkata Knight Riders
# 1118             Delhi Daredevils          Sunrisers Hyderabad
# 1119             Delhi Daredevils          Sunrisers Hyderabad
# 1120      Rising Pune Supergiants              Kings XI Punjab
# 1121      Rising Pune Supergiants              Kings XI Punjab
# 1122                Gujarat Lions               Mumbai Indians
# 1123                Gujarat Lions               Mumbai Indians
# 1124        Kolkata Knight Riders          Sunrisers Hyderabad
# 1125        Kolkata Knight Riders          Sunrisers Hyderabad
# 1126             Delhi Daredevils  Royal Challengers Bangalore
# 1127             Delhi Daredevils  Royal Challengers Bangalore
# 1128                Gujarat Lions  Royal Challengers Bangalore
# 1129                Gujarat Lions  Royal Challengers Bangalore
# 1130          Sunrisers Hyderabad        Kolkata Knight Riders
# 1131          Sunrisers Hyderabad        Kolkata Knight Riders
# 1132                Gujarat Lions          Sunrisers Hyderabad
# 1133                Gujarat Lions          Sunrisers Hyderabad
# 1134  Royal Challengers Bangalore          Sunrisers Hyderabad
# 1135  Royal Challengers Bangalore          Sunrisers Hyderabad
#
#                            winner  total
# 0           Kolkata Knight Riders    222
# 1           Kolkata Knight Riders     82
# 2             Chennai Super Kings    240
# 3             Chennai Super Kings    207
# 4                Delhi Daredevils    132
# 5                Delhi Daredevils    129
# 6     Royal Challengers Bangalore    165
# 7     Royal Challengers Bangalore    166
# 8           Kolkata Knight Riders    110
# 9           Kolkata Knight Riders    112
# 10               Rajasthan Royals    166
# 11               Rajasthan Royals    168
# 12               Delhi Daredevils    142
# 13               Delhi Daredevils    143
# 14            Chennai Super Kings    208
# 15            Chennai Super Kings    202
# 16               Rajasthan Royals    214
# 17               Rajasthan Royals    217
# 18                Kings XI Punjab    182
# 19                Kings XI Punjab    116
# 20               Rajasthan Royals    138
# 21               Rajasthan Royals    135
# 22            Chennai Super Kings    152
# 23            Chennai Super Kings    147
# 24                Deccan Chargers    155
# 25                Deccan Chargers    154
# 26                Kings XI Punjab    158
# 27                Kings XI Punjab    162
# 28            Chennai Super Kings    178
# 29            Chennai Super Kings    165
# ...                           ...    ...
# 1106          Sunrisers Hyderabad    179
# 1107          Sunrisers Hyderabad    180
# 1108               Mumbai Indians    126
# 1109               Mumbai Indians    206
# 1110  Royal Challengers Bangalore    183
# 1111  Royal Challengers Bangalore    186
# 1112      Rising Pune Supergiants    121
# 1113      Rising Pune Supergiants     76
# 1114  Royal Challengers Bangalore    120
# 1115  Royal Challengers Bangalore    211
# 1116                Gujarat Lions    125
# 1117                Gujarat Lions    124
# 1118             Delhi Daredevils    161
# 1119             Delhi Daredevils    158
# 1120      Rising Pune Supergiants    172
# 1121      Rising Pune Supergiants    173
# 1122                Gujarat Lions    173
# 1123                Gujarat Lions    172
# 1124        Kolkata Knight Riders    171
# 1125        Kolkata Knight Riders    149
# 1126  Royal Challengers Bangalore    138
# 1127  Royal Challengers Bangalore    139
# 1128  Royal Challengers Bangalore    158
# 1129  Royal Challengers Bangalore    159
# 1130          Sunrisers Hyderabad    140
# 1131          Sunrisers Hyderabad    162
# 1132          Sunrisers Hyderabad    162
# 1133          Sunrisers Hyderabad    163
# 1134          Sunrisers Hyderabad    200
# 1135          Sunrisers Hyderabad    208
#
# [1136 rows x 7 columns]

# %%
filtered_df=filtered_df[filtered_df['total']>=200]
scoring_= filtered_df[(filtered_df['total']>=200) & (filtered_df['inning']==2)]
scoring_
# Out:
#       match_code                 batting_team  inning  \
# 3         335983              Kings XI Punjab       2
# 15        335989               Mumbai Indians       2
# 17        335990             Rajasthan Royals       2
# 100       336033          Chennai Super Kings       2
# 231       419107             Rajasthan Royals       2
# 241       419112  Royal Challengers Bangalore       2
# 289       419137             Rajasthan Royals       2
# 292       419139              Kings XI Punjab       2
# 395       501223              Kings XI Punjab       2
# 514       548318          Chennai Super Kings       2
# 791       729283              Kings XI Punjab       2
# 860       734007              Kings XI Punjab       2
# 900       734047          Chennai Super Kings       2
# 903       734049        Kolkata Knight Riders       2
# 1134      981019  Royal Challengers Bangalore       2
#
#                             team1                        team2  \
# 3                 Kings XI Punjab          Chennai Super Kings
# 15            Chennai Super Kings               Mumbai Indians
# 17                Deccan Chargers             Rajasthan Royals
# 100           Chennai Super Kings             Rajasthan Royals
# 231                Mumbai Indians             Rajasthan Royals
# 241   Royal Challengers Bangalore              Kings XI Punjab
# 289           Chennai Super Kings             Rajasthan Royals
# 292         Kolkata Knight Riders              Kings XI Punjab
# 395              Delhi Daredevils              Kings XI Punjab
# 514           Chennai Super Kings  Royal Challengers Bangalore
# 791           Chennai Super Kings              Kings XI Punjab
# 860           Sunrisers Hyderabad              Kings XI Punjab
# 900           Chennai Super Kings              Kings XI Punjab
# 903         Kolkata Knight Riders              Kings XI Punjab
# 1134  Royal Challengers Bangalore          Sunrisers Hyderabad
#
#                            winner  total
# 3             Chennai Super Kings    207
# 15            Chennai Super Kings    202
# 17               Rajasthan Royals    217
# 100              Rajasthan Royals    201
# 231                Mumbai Indians    208
# 241   Royal Challengers Bangalore    204
# 289           Chennai Super Kings    223
# 292               Kings XI Punjab    204
# 395              Delhi Daredevils    202
# 514           Chennai Super Kings    208
# 791               Kings XI Punjab    206
# 860               Kings XI Punjab    211
# 900               Kings XI Punjab    202
# 903         Kolkata Knight Riders    200
# 1134          Sunrisers Hyderabad    200

# %%
scoring_and_winning = scoring_[scoring_['batting_team']== scoring_['winner']]
scoring_and_winning
# Out:
#      match_code                 batting_team  inning  \
# 17       335990             Rajasthan Royals       2
# 241      419112  Royal Challengers Bangalore       2
# 292      419139              Kings XI Punjab       2
# 514      548318          Chennai Super Kings       2
# 791      729283              Kings XI Punjab       2
# 860      734007              Kings XI Punjab       2
# 903      734049        Kolkata Knight Riders       2
#
#                            team1                        team2  \
# 17               Deccan Chargers             Rajasthan Royals
# 241  Royal Challengers Bangalore              Kings XI Punjab
# 292        Kolkata Knight Riders              Kings XI Punjab
# 514          Chennai Super Kings  Royal Challengers Bangalore
# 791          Chennai Super Kings              Kings XI Punjab
# 860          Sunrisers Hyderabad              Kings XI Punjab
# 903        Kolkata Knight Riders              Kings XI Punjab
#
#                           winner  total
# 17              Rajasthan Royals    217
# 241  Royal Challengers Bangalore    204
# 292              Kings XI Punjab    204
# 514          Chennai Super Kings    208
# 791              Kings XI Punjab    206
# 860              Kings XI Punjab    211
# 903        Kolkata Knight Riders    200

# %%
percent=len(scoring_and_winning)/len(scoring_)
print('the chances are:"+"{:.2%}'.format(percent))
# Out:
# the chances are:"+"46.67%

# %% [markdown]
# ### Every season has that one team which is outperforming others and is in great form. Which team has the highest win counts in their respective seasons ?

# %%
df_ipl['date']=pd.to_datetime(df_ipl['date'])
df_ipl['year']= df_ipl['date'].dt.year
df1=df_ipl.drop_duplicates(subset='match_code',keep='first')
X=df1.groupby('year')['winner'].describe()
X.drop(columns)
# Out:
#      count unique                    top freq
# year
# 2008    58      8       Rajasthan Royals   13
# 2009    56      8       Delhi Daredevils   10
# 2010    59      8         Mumbai Indians   11
# 2011    72     10    Chennai Super Kings   11
# 2012    74      9  Kolkata Knight Riders   12
# 2013    74      9         Mumbai Indians   13
# 2014    59      8        Kings XI Punjab   12
# 2015    56      8         Mumbai Indians   10
# 2016    60      8    Sunrisers Hyderabad   11
